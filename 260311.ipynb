# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/colab/blob/main/260311.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 파이썬 특징
# 1) 인터프리터 언어
# 2) 동적타입언어=하나의 변수가 여러 자료 가질 수 있다
# 3) 플랫폼 독립적 언어
#
# python kywords rules
# 1) 소문자, 대문자, 숫자, _(underscore) 구분한다
# 2) 숫자로 시작할 수 없다
# 3) 키워드를 식별자로 사용 불가하다
# 4) 특정 심벌 사용불가(underscore 제외)
# 5) 길이는 상관없다
#
#
# Statement
# -multiline statement
# 역슬래시
# 세미콜론
# 자료형 괄호, 대활호, 중괄호
#
# 들여쓰기(identation)
#
# 주석(comments)
