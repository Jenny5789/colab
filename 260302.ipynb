# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/colab/blob/main/260302.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2026.03.04.
#
#
# ---
#
#
# *  keyword : Github에 정리하기, 포트폴리오 만들기
#
# ---
#
#
# > 프로그래밍(언어), **컴퓨팅 사고력**, 로우 레벨 언어, 하이 레벨 언어, 컴파일러 언어, 인터프리터 언어, 컴퓨팅 사고, **변수(명)**, C언어, python
#
#
# ---
#
#
# > *  **THINK WHY!!!!!!**
# > *  프로그래밍 언어->**"암기 후 이해"**
# > *   **무엇을 코딩할 것인가???** = 진로고민
#
# ---
