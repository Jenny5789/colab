# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/colab/blob/main/260312.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python variables(변수)

# %%
website = "kopo.ac.kr"
print (website)
# Out:
# kopo.ac.kr

# %%
website = "kopo.ac.kr"
print (website)
website = "naver.com"
print(website)
website = 1
print(website)
# Out:
# kopo.ac.kr
# naver.com
# 1

# %%
a,b,c = 10,5.2, "kopo"
print(a)
print(b)
print(c)
# Out:
# 10
# 5.2
# kopo

# %%
# if 식별자와 리터널의 개수가 다르다면?

a,b,c = 10, 5.2
print(a)
print(b)
print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_358/2638820777.py in <cell line: 0>()
# ----> 1 a,b,c = 10, 5.2
#       2 print(a)
#       3 print(b)
#       4 print(c)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
a = b = c = "kopo"
print(a)
print(b)
print(c)
# Out:
# kopo
# kopo
# kopo

# %%
num1 = mum2 = num3 = 20
#'num1 =mun2' 확인 -> num2은 값이 아님/ num2 = num3' 확인 -> num3은 값이 아님/num3 =20' 확인 -> 값이 있어--> 20 대입
# 20의 주소를 num3-> num2-> num1로 저장함

# %% [markdown]
# Python constants(상수)

# %%
a=10

# %%
print(id(10), id(a))         # 'id' 주소의 위치를 알려줌
# Out:
# 11654664 11654664

# %%
b = a
print(id(b))
# Out:
# 11654664

# %%
a = a + 1
print(a)
print(id(a))
# Out:
# 11
# 11654696

# %%
print(id(10), id(11))
# Out:
# 11654664 11654696

# %%
# constant.py
PI = 3.14

# main.py
import constant

printf(constant.PI)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_358/3278611923.py in <cell line: 0>()
#       3
#       4 # main.py
# ----> 5 import constant
#       6
#       7 printf(constant.PI)
#
# ModuleNotFoundError: No module named 'constant'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Literal

# %%
a = 0b1010 # Binary Literal
b = 100 # Decimal Literal
c = 0o310 # Ocatal Literal
d = 0x12c # Hexadecimal Literal

# Float Literal
float_1 = 10.5
float_2 = 1.5e2

# Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2)
print(x, x.imag. x.real)
# Out:
# 10 100 200 300
# 10.5 150.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_358/2578348220.py in <cell line: 0>()
#      13 print(a, b, c, d)
#      14 print(float_1, float_2)
# ---> 15 print(x, x.imag. x.real)
#
# AttributeError: 'float' object has no attribute 'x'

# %%
x = (1 == True)
y = (1 == False)
a = True + 4
b = False + 10

print("x is", x)
print("y is", y)
print("a:", a)
print("b:", b)
# Out:
# x is True
# y is False
# a: 5
# b: 10

# %%
strings = "This is Python"
char = "c"
multiline_str = """This is a multline string with more than one line code."""
unicode = u"\u00dcnic\u00f6de"
raw_str = r"raw \ n string"

print(strings)
print(char)
print(multiline_str)
print(unicode)          #unicode
print(raw_str)
# Out:
# This is Python
# c
# This is a multline string with more than one line code.
# Ünicöde
# raw \ n string

# %% [markdown]
# Special literal & literal collections

# %%
drink = "Available"
food = None

def menu(x):
    if x == drink:
        print(drink)
    else:
        print(food)

menu(drink)
menu(food)
# Out:
# Available
# None

# %%
fruits = ["apple", "mango", "orange"]   #list
numbers = (1, 2, 3)  #tuple
alphabets = {'a':'apple', 'b':'ball', 'c':'cat'}  #dictionary
vowels = {'a', 'e', 'i', 'o', 'u'}  #set

print(fruits)
print(numbers)
print(alphabets)
print(vowels)
# Out:
# ['apple', 'mango', 'orange']
# (1, 2, 3)
# {'a': 'apple', 'b': 'ball', 'c': 'cat'}
# {'u', 'a', 'e', 'i', 'o'}

# %% [markdown]
# Python data types: number

# %%
# output : 5 is type of <class 'int'>
a = 5
print(a, "is type of", type(a))

       # type(a)-> Q: a이 뭐니?  A : int(등)야.



# output : 2.0 is type of <class 'float'>
a = 2.0
print(a, "is type of", type(a))



# output : (1+2j) is complex number? True
a = 1+2j
print(a, "is complex number?", isinstance(1+2j,complex))


# isinstance(알고 싶은 것, 클래스)
# isinstanc(a,b) -> Q: a는 b의 클래스가 맞니? A : True(맞아)/False(아니야)
# Out:
# 5 is type of <class 'int'>
# 2.0 is type of <class 'float'>
# (1+2j) is complex number? True

# %% [markdown]
# list/tuple/dict/set

# %% [markdown]
# LIST

# %%
list_1 = [1,2,3,4,5]

print(list_1[0])
# Out:
# 1

# %%
print(list_1[0] + list_1[1])
# Out:
# 3

# %%
list_1[0:2]              # slices
# Out:
# [1, 2]

# %%
list_1[0,1]              # list

# slice 라 함 그럼 ','으로는 될까? 궁금증을 가져보기
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_358/4138229595.py in <cell line: 0>()
# ----> 1 list_1[0,1]              # list
#
# TypeError: list indices must be integers or slices, not tuple

# %%
list_2 = [0:4]
# valid syntax 으로 하려면 ':'으로 해볼까?
# 안되는구나. 결론: 정의하려면 ','으로 list 을 작성해야하는구나!
# Out:
#   File "/tmp/ipykernel_358/1304259589.py", line 1
#     list_2 = [0:4]           # list_2 ':'
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# list의 다른 item이 다른 유형도 가능하다

# %%
list_1 = ["구가은", 20, "여", True, ["부", "모", "남동생"]]    #list 안에 문자, 숫자, 논리, 리스트 안의 리스트가 있다
print(list_1[0])
print(list_1[4])

print(list_1[4][0])
# Out:
# 구가은
# ['부', '모', '남동생']
# 부

# %% [markdown]
# TUPLE

# %%
t = (5, 'program', 1+3j)

# t[1] = 'program'
print("t[1] = ", t[1])

# t[0:3] = (5, 'program', (1+3j))
print("t[0:3] = ", t[0:3])

# Generates error
# Tuples are immutable
t[0] = 10           # list와 별개로 선언 이후에는 변경 불가
# Out:
# t[1] =  program
# t[0:3] =  (5, 'program', (1+3j))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_358/1477982893.py in <cell line: 0>()
#       9 # Generates error
#      10 # Tuples are immutable
# ---> 11 t[0] = 10           # list와 별개로 선언 이후에는 변경 불가
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# STRING

# %%
s = "This is a string"
print(s)
s = '''A multiline string'''
print(s)
# Out:
# This is a string
# A multiline string

# %%
s = 'Hello world!'

# s[4] = 'o'
print("s[4] = ", s[4])

# s[6:11] = 'world'
print("s[6:11] = ", s[6:11])

# Generates error : strings are immutable in python
s[5] = 'd'     # 변경 불가
# Out:
# s[4] =  o
# s[6:11] =  world
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_358/3297961766.py in <cell line: 0>()
#       8
#       9 # Generates error : strings are immutable in python
# ---> 10 s[5] = 'd'
#
# TypeError: 'str' object does not support item assignment

# %%
문자열_1 = "송현우 이동현"
enumerate(문자열_1)           # "송현우 이동현"의 주소 위치를 알려줌

# %%
print(enumerate(문자열_1))

# %%
print(list(enumerate(문자열_1)))             #enumerate 의 주소 위치에 있는 값을 list로(내가 사용할 수 있는 형태) 바꿔줌
# Out:
# [(0, '송'), (1, '현'), (2, '우'), (3, ' '), (4, '이'), (5, '동'), (6, '현')]

# %%
list_1 = ["서지섭", "고규현", "김기욱"]
print(list(enumerate(list_1)))
# Out:
# [(0, '서지섭'), (1, '고규현'), (2, '김기욱')]

# %%
str = 'cold'
print('len(str) = ', len(str))           # 문자 길이
# Out:
# len(str) =  4

# %% [markdown]
# set

# %%
a = {1,2,2,3,3,3}
print(a)
# Out:
# {1, 2, 3}

# %%
a = {5,2,3,1,4}

# printing set variable
print("a = ",a)

# data type of variable a
print(type(a))
# Out:
# a =  {1, 2, 3, 4, 5}
# <class 'set'>

# %% [markdown]
# dictionary

# %%
d = {1:'value','key':2}
print(type(d))

print("d[1] = ", d[1])    # d[1]은 key 값이 1인 걸 의미함. value값인 value 를 print.
print("d['key'] = ", d['key'])    #d['key']은 key 값이 'key'인 value 값을 print.

# Generates error
print("d[2] = ", d[2])    # key값이 2가 없으므로 오류발생
# Out:
# <class 'dict'>
# d[1] =  value
# d['key'] =  2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_358/3847393614.py in <cell line: 0>()
#       6
#       7 # Generates error
# ----> 8 print("d[2] = ", d[2])    # key값이 2가 없으므로 오류발생
#
# KeyError: 2

# %% [markdown]
# Type casting(형변환)

# %%
num_int = 123
num_flo = 1.23

num_new = num_int + num_flo
print("datatype of num_int:", type(num_int))
print("datatype of num_flo:", type(num_flo))
# Out:
# datatype of num_int: <class 'int'>
# datatype of num_flo: <class 'float'>

# %% [markdown]
# print

# %%
print(1,2,3,4,"t")
# Out:
# 1 2 3 4 t

# %%
print(1,2,3,4,"t",sep='\n') #1입력 줄 바꿈 2 입력 줄 바꿈 ... 반복
# Out:
# 1
# 2
# 3
# 4
# t

# %%
print(1,2,3,'\n',4,"t")         # 중간에 줄 바꿈
# Out:
# 1 2 3
#  4 t

# %%
print(1,2,3, end= '\t')         # 줄바꿈 대신 tab
print(4,5,6)                    # 원래있는 줄 바꿈
print(7,8,9)
# Out:
# 1 2 3	4 5 6
# 7 8 9

# %% [markdown]
# str.format

# %% [markdown]
# input

# %% [markdown]
# import

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
from math import pi
pi
# Out:
# 3.141592653589793
